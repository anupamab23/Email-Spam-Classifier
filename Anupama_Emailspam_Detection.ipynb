# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import warnings
warnings.filterwarnings("ignore")

# %%
# %matplotlib inline

# %%
from sklearn.model_selection import train_test_split

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
from keras.layers import Embedding

# %%
from keras.layers import GlobalAveragePooling1D

# %%
from keras.callbacks import EarlyStopping

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
from tensorflow.keras.optimizers import SGD

# %%
path = 'C:/Users/aksha/Documents/SpamCollection.txt'
messages = pd.read_csv(path, sep ='\t',names=["label", "message"])
messages[:3]
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...

# %%
messages.describe()
# Out:
#        label                 message
# count   5572                    5572
# unique     2                    5169
# top      ham  Sorry, I'll call later
# freq    4825                      30

# %%
duplicatedRow = messages[messages.duplicated()]
print(duplicatedRow[:5])
# Out:
#     label                                            message
# 103   ham  As per your request 'Melle Melle (Oru Minnamin...
# 154   ham  As per your request 'Melle Melle (Oru Minnamin...
# 207   ham  As I entered my cabin my PA said, '' Happy B'd...
# 223   ham                             Sorry, I'll call later
# 326   ham                   No calls..messages..missed calls

# %%
messages.groupby('label').describe().T
# Out:
# label                              ham  \
# message count                     4825
#         unique                    4516
#         top     Sorry, I'll call later
#         freq                        30
#
# label                                                        spam
# message count                                                 747
#         unique                                                653
#         top     Please call our customer service representativ...
#         freq                                                    4

# %%
ham_msg = messages[messages.label =='ham']
spam_msg = messages[messages.label=='spam']

ham_msg_txt = " ".join(ham_msg.message.to_numpy().tolist())
spam_msg_txt = " ".join(spam_msg.message.to_numpy().tolist())

# %%
ham_msg_wcloud = WordCloud(width =520, height =260, stopwords=STOPWORDS,max_font_size=50, background_color ="red", colormap='Blues').generate(ham_msg_txt)
plt.figure(figsize=(16,10))
plt.imshow(ham_msg_wcloud, interpolation='bilinear')
plt.axis('off') # turn off axis
plt.show()

# %%
spam_msg_wcloud = WordCloud(width =520, height =260, stopwords=STOPWORDS,max_font_size=50, background_color ="black", colormap='Spectral_r').generate(spam_msg_txt)
plt.figure(figsize=(16,10))
plt.imshow(spam_msg_wcloud, interpolation='bilinear')
plt.axis('off') # turn off axis
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(messages.label)
# Percentage of spam messages
(len(spam_msg)/len(ham_msg))*100
# Out:
# 15.481865284974095

# %%
# one way to fix imbalanced data is to downsample the ham message count to the spam message count
ham_msg_df = ham_msg.sample(n = len(spam_msg), random_state = 44)
spam_msg_df = spam_msg

#check the shape now, it must be te same!
print(ham_msg_df.shape, spam_msg_df.shape)

#check graph for better visualization 
msg_df = ham_msg_df.append(spam_msg_df).reset_index(drop=True)
plt.figure(figsize=(8,6))
sns.countplot(msg_df.label)
plt.title('Distribution of ham and spam messages (after downsampling)')
plt.xlabel('Message labels')
# Out:
# (747, 2) (747, 2)
# Text(0.5, 0, 'Message labels')

# %%
# Get length column for each text
msg_df['text_length'] = msg_df['message'].apply(len)

#Calculate average length by label types
labels = msg_df.groupby('label').mean()
labels
# Out:
#        text_length
# label
# ham      73.238286
# spam    138.670683

# %%
# Map ham label as 0 and spam as 1
msg_df['msg_type']= msg_df['label'].map({'ham': 0, 'spam': 1})
msg_label = msg_df['msg_type'].values

# Split data into train and test
train_msg, test_msg, train_labels, test_labels = train_test_split(msg_df['message'], msg_label, test_size=0.2, random_state=434)

# %%
# Defining pre-processing hyperparameters
max_len = 50 
trunc_type = "post" 
padding_type = "post" 
oov_tok = "<OOV>" 
vocab_size = 500

# %%
tokenizer = Tokenizer(num_words = vocab_size, char_level=False, oov_token = oov_tok)
tokenizer.fit_on_texts(train_msg)

# %%
# Get the word_index 
word_index = tokenizer.word_index
word_index
# Out:
# {'<OOV>': 1,
#  'to': 2,
#  'you': 3,
#  'a': 4,
#  'i': 5,
#  'call': 6,
#  'the': 7,
#  'u': 8,
#  'your': 9,
#  'for': 10,
#  'is': 11,
#  '2': 12,
#  'and': 13,
#  'now': 14,
#  'free': 15,
#  'or': 16,
#  'on': 17,
#  'in': 18,
#  'ur': 19,
#  'have': 20,
#  '4': 21,
#  'txt': 22,
#  'of': 23,
#  'are': 24,
#  'with': 25,
#  'me': 26,
#  'from': 27,
#  'text': 28,
#  'get': 29,
#  'my': 30,
#  'it': 31,
#  'stop': 32,
#  'just': 33,
#  'mobile': 34,
#  'this': 35,
#  'will': 36,
#  'be': 37,
#  'no': 38,
#  'that': 39,
#  'claim': 40,
#  'reply': 41,
#  'can': 42,
#  'so': 43,
#  'send': 44,
#  'www': 45,
#  'we': 46,
#  'only': 47,
#  'our': 48,
#  'not': 49,
#  'out': 50,
#  'at': 51,
#  'do': 52,
#  'if': 53,
#  'prize': 54,
#  'new': 55,
#  'go': 56,
#  'cash': 57,
#  'but': 58,
#  '150p': 59,
#  'uk': 60,
#  '1': 61,
#  'nokia': 62,
#  'who': 63,
#  't': 64,
#  'all': 65,
#  'win': 66,
#  'please': 67,
#  'won': 68,
#  'up': 69,
#  'tone': 70,
#  'when': 71,
#  "i'm": 72,
#  'week': 73,
#  'been': 74,
#  'what': 75,
#  'msg': 76,
#  '50': 77,
#  'com': 78,
#  'urgent': 79,
#  'how': 80,
#  'service': 81,
#  'phone': 82,
#  'time': 83,
#  'contact': 84,
#  'co': 85,
#  'love': 86,
#  'day': 87,
#  'know': 88,
#  'want': 89,
#  '18': 90,
#  'by': 91,
#  'today': 92,
#  '16': 93,
#  'has': 94,
#  'per': 95,
#  'was': 96,
#  'min': 97,
#  'r': 98,
#  'am': 99,
#  'as': 100,
#  'ok': 101,
#  'c': 102,
#  'like': 103,
#  'customer': 104,
#  'guaranteed': 105,
#  'see': 106,
#  'her': 107,
#  'its': 108,
#  'cs': 109,
#  'need': 110,
#  'every': 111,
#  'any': 112,
#  'then': 113,
#  'hi': 114,
#  'number': 115,
#  'good': 116,
#  'message': 117,
#  'line': 118,
#  'back': 119,
#  'there': 120,
#  'gt': 121,
#  'draw': 122,
#  'find': 123,
#  'chat': 124,
#  'they': 125,
#  'lt': 126,
#  'awarded': 127,
#  '3': 128,
#  'more': 129,
#  'got': 130,
#  'dont': 131,
#  'tell': 132,
#  'take': 133,
#  'should': 134,
#  'camera': 135,
#  'sms': 136,
#  '£1': 137,
#  'wk': 138,
#  '£1000': 139,
#  'an': 140,
#  'mins': 141,
#  'receive': 142,
#  'n': 143,
#  'yes': 144,
#  'd': 145,
#  'she': 146,
#  'dear': 147,
#  'sorry': 148,
#  'live': 149,
#  'po': 150,
#  'box': 151,
#  'latest': 152,
#  'chance': 153,
#  'rate': 154,
#  'going': 155,
#  'video': 156,
#  'holiday': 157,
#  'here': 158,
#  '150ppm': 159,
#  'about': 160,
#  'one': 161,
#  'home': 162,
#  'apply': 163,
#  'thanks': 164,
#  "don't": 165,
#  'shows': 166,
#  'award': 167,
#  'pls': 168,
#  'ü': 169,
#  'landline': 170,
#  'tones': 171,
#  'come': 172,
#  'code': 173,
#  'make': 174,
#  'think': 175,
#  'still': 176,
#  'network': 177,
#  'ringtone': 178,
#  'last': 179,
#  's': 180,
#  'after': 181,
#  'selected': 182,
#  '1st': 183,
#  "it's": 184,
#  'orange': 185,
#  'had': 186,
#  'special': 187,
#  'give': 188,
#  'account': 189,
#  'night': 190,
#  'e': 191,
#  'much': 192,
#  'next': 193,
#  'he': 194,
#  'offer': 195,
#  'great': 196,
#  'weekly': 197,
#  'b': 198,
#  '500': 199,
#  'where': 200,
#  '£100': 201,
#  'valid': 202,
#  'music': 203,
#  'hey': 204,
#  'mob': 205,
#  '10p': 206,
#  'play': 207,
#  'collect': 208,
#  'tomorrow': 209,
#  'miss': 210,
#  'way': 211,
#  'cost': 212,
#  'entry': 213,
#  '8007': 214,
#  'hope': 215,
#  'national': 216,
#  'some': 217,
#  'collection': 218,
#  'why': 219,
#  'da': 220,
#  '10': 221,
#  'vouchers': 222,
#  'meet': 223,
#  'trying': 224,
#  '000': 225,
#  'well': 226,
#  'someone': 227,
#  'name': 228,
#  'word': 229,
#  'over': 230,
#  'games': 231,
#  '£500': 232,
#  'http': 233,
#  'poly': 234,
#  '5': 235,
#  'texts': 236,
#  '86688': 237,
#  'care': 238,
#  'club': 239,
#  'todays': 240,
#  'price': 241,
#  'im': 242,
#  'oh': 243,
#  'babe': 244,
#  'await': 245,
#  'too': 246,
#  'sae': 247,
#  'hot': 248,
#  'sexy': 249,
#  'said': 250,
#  "c's": 251,
#  'end': 252,
#  'bonus': 253,
#  'land': 254,
#  'gift': 255,
#  'bt': 256,
#  'delivery': 257,
#  'us': 258,
#  'help': 259,
#  'yours': 260,
#  'join': 261,
#  'x': 262,
#  '£2000': 263,
#  'opt': 264,
#  'attempt': 265,
#  'really': 266,
#  'voucher': 267,
#  "i'll": 268,
#  'xxx': 269,
#  'dating': 270,
#  'which': 271,
#  'right': 272,
#  'doing': 273,
#  'update': 274,
#  'colour': 275,
#  '£3': 276,
#  'operator': 277,
#  '£5000': 278,
#  'services': 279,
#  'private': 280,
#  'friend': 281,
#  'also': 282,
#  'did': 283,
#  'top': 284,
#  '12hrs': 285,
#  'try': 286,
#  'say': 287,
#  '750': 288,
#  'half': 289,
#  'waiting': 290,
#  'enjoy': 291,
#  'sent': 292,
#  'pic': 293,
#  'work': 294,
#  '2nd': 295,
#  'lor': 296,
#  'double': 297,
#  'mobileupd8': 298,
#  'would': 299,
#  'quiz': 300,
#  'real': 301,
#  '100': 302,
#  '08000930705': 303,
#  'order': 304,
#  'm': 305,
#  'worth': 306,
#  'content': 307,
#  'xmas': 308,
#  '£350': 309,
#  'wanna': 310,
#  'unsubscribe': 311,
#  'ltd': 312,
#  'wat': 313,
#  'tried': 314,
#  'around': 315,
#  'row': 316,
#  'days': 317,
#  '£250': 318,
#  'guys': 319,
#  'later': 320,
#  '6': 321,
#  'face': 322,
#  'hello': 323,
#  'speak': 324,
#  'camcorder': 325,
#  'charged': 326,
#  'were': 327,
#  'first': 328,
#  'final': 329,
#  'congratulations': 330,
#  'wkly': 331,
#  '87066': 332,
#  'reveal': 333,
#  'money': 334,
#  'easy': 335,
#  'rental': 336,
#  'balance': 337,
#  'cant': 338,
#  'wait': 339,
#  'another': 340,
#  'freemsg': 341,
#  'pounds': 342,
#  'suite342': 343,
#  '2lands': 344,
#  'ya': 345,
#  'life': 346,
#  'start': 347,
#  'off': 348,
#  '08000839402': 349,
#  'phones': 350,
#  'best': 351,
#  'god': 352,
#  'people': 353,
#  'statement': 354,
#  'points': 355,
#  'identifier': 356,
#  'expires': 357,
#  'keep': 358,
#  'wap': 359,
#  'amp': 360,
#  'before': 361,
#  'secret': 362,
#  'ready': 363,
#  'info': 364,
#  '£2': 365,
#  'winner': 366,
#  'done': 367,
#  'use': 368,
#  'mobiles': 369,
#  'auction': 370,
#  'early': 371,
#  'k': 372,
#  'soon': 373,
#  'fun': 374,
#  'g': 375,
#  'may': 376,
#  'very': 377,
#  'valued': 378,
#  'pics': 379,
#  '0800': 380,
#  'messages': 381,
#  'pick': 382,
#  'friends': 383,
#  'could': 384,
#  'yet': 385,
#  'ringtones': 386,
#  'even': 387,
#  'custcare': 388,
#  'rates': 389,
#  'between': 390,
#  'looking': 391,
#  'again': 392,
#  'sleep': 393,
#  '2003': 394,
#  '800': 395,
#  'savamob': 396,
#  'offers': 397,
#  'tv': 398,
#  'f': 399,
#  'eg': 400,
#  'anything': 401,
#  'admirer': 402,
#  'thinks': 403,
#  'comes': 404,
#  'reward': 405,
#  'net': 406,
#  'year': 407,
#  'morning': 408,
#  'mates': 409,
#  "can't": 410,
#  'important': 411,
#  'txts': 412,
#  'heart': 413,
#  'shopping': 414,
#  'gr8': 415,
#  'game': 416,
#  'call2optout': 417,
#  'shop': 418,
#  '03': 419,
#  'many': 420,
#  'yr': 421,
#  'comp': 422,
#  'std': 423,
#  'guess': 424,
#  'msgs': 425,
#  "didn't": 426,
#  'un': 427,
#  'redeemed': 428,
#  '7': 429,
#  'wan': 430,
#  'charge': 431,
#  'bit': 432,
#  'weeks': 433,
#  "you're": 434,
#  'numbers': 435,
#  'anytime': 436,
#  'them': 437,
#  'tc': 438,
#  'called': 439,
#  'being': 440,
#  'direct': 441,
#  'leave': 442,
#  '11': 443,
#  'pobox': 444,
#  'him': 445,
#  'w1j6hl': 446,
#  'news': 447,
#  'ntt': 448,
#  'girl': 449,
#  'his': 450,
#  'thought': 451,
#  'player': 452,
#  'currently': 453,
#  'sex': 454,
#  'luv': 455,
#  'england': 456,
#  'eve': 457,
#  'down': 458,
#  'buy': 459,
#  'congrats': 460,
#  'having': 461,
#  'ts': 462,
#  'motorola': 463,
#  'calls': 464,
#  'complimentary': 465,
#  'caller': 466,
#  'month': 467,
#  'charity': 468,
#  'trip': 469,
#  'matches': 470,
#  'ipod': 471,
#  'minutes': 472,
#  'fuck': 473,
#  'ac': 474,
#  '04': 475,
#  '£150': 476,
#  'discount': 477,
#  'place': 478,
#  '9': 479,
#  'getzed': 480,
#  'check': 481,
#  'ldew': 482,
#  'crazy': 483,
#  'minute': 484,
#  'ending': 485,
#  'enough': 486,
#  'id': 487,
#  'already': 488,
#  'talk': 489,
#  'inc': 490,
#  'digital': 491,
#  'dogging': 492,
#  'lucky': 493,
#  're': 494,
#  'late': 495,
#  'same': 496,
#  'ldn': 497,
#  'lar': 498,
#  'feel': 499,
#  'date': 500,
#  'age': 501,
#  'into': 502,
#  'fancy': 503,
#  'hg': 504,
#  'ill': 505,
#  'age16': 506,
#  'area': 507,
#  'within': 508,
#  '08712460324': 509,
#  "t's": 510,
#  "i've": 511,
#  'little': 512,
#  'v': 513,
#  '87077': 514,
#  'tonight': 515,
#  'stuff': 516,
#  'yeah': 517,
#  'ip4': 518,
#  '5we': 519,
#  'boy': 520,
#  'asked': 521,
#  '20p': 522,
#  'song': 523,
#  'polys': 524,
#  'plus': 525,
#  'representative': 526,
#  'match': 527,
#  'hit': 528,
#  'credit': 529,
#  'visit': 530,
#  '00': 531,
#  'lunch': 532,
#  'does': 533,
#  'pm': 534,
#  'let': 535,
#  'each': 536,
#  '£800': 537,
#  'cd': 538,
#  'cool': 539,
#  'weekend': 540,
#  'welcome': 541,
#  'away': 542,
#  'information': 543,
#  'question': 544,
#  'answer': 545,
#  'computer': 546,
#  'part': 547,
#  'man': 548,
#  'guy': 549,
#  'book': 550,
#  'specially': 551,
#  '£10': 552,
#  'enter': 553,
#  'smiling': 554,
#  'dude': 555,
#  'xx': 556,
#  'cos': 557,
#  'user': 558,
#  'log': 559,
#  'better': 560,
#  'evening': 561,
#  'happy': 562,
#  'class': 563,
#  'mind': 564,
#  'wid': 565,
#  '150': 566,
#  'other': 567,
#  'simple': 568,
#  '£200': 569,
#  'store': 570,
#  'shit': 571,
#  'hmv': 572,
#  'del': 573,
#  'terms': 574,
#  'flag': 575,
#  'calling': 576,
#  'thk': 577,
#  'bluetooth': 578,
#  'ans': 579,
#  'alone': 580,
#  'etc': 581,
#  'bx420': 582,
#  'either': 583,
#  'busy': 584,
#  'baby': 585,
#  '50p': 586,
#  'sony': 587,
#  'reach': 588,
#  'liao': 589,
#  'sunshine': 590,
#  'saturday': 591,
#  '0870': 592,
#  'summer': 593,
#  'getting': 594,
#  'yo': 595,
#  'choose': 596,
#  'look': 597,
#  'rcvd': 598,
#  '08718720201': 599,
#  'freephone': 600,
#  'details': 601,
#  'arrive': 602,
#  'red': 603,
#  'dvd': 604,
#  'bid': 605,
#  '85023': 606,
#  'pobox84': 607,
#  '2004': 608,
#  '06': 609,
#  'town': 610,
#  'frnd': 611,
#  'show': 612,
#  'rply': 613,
#  'nothing': 614,
#  'tncs': 615,
#  'these': 616,
#  'vodafone': 617,
#  '08712300220': 618,
#  'standard': 619,
#  'hours': 620,
#  'credits': 621,
#  'anyway': 622,
#  'flights': 623,
#  'must': 624,
#  'biz': 625,
#  'haha': 626,
#  'yup': 627,
#  "there's": 628,
#  'world': 629,
#  'sub': 630,
#  'than': 631,
#  '3030': 632,
#  'no1': 633,
#  'txting': 634,
#  'long': 635,
#  'onto': 636,
#  'fantastic': 637,
#  'awaiting': 638,
#  'driving': 639,
#  'access': 640,
#  'college': 641,
#  'o2': 642,
#  'vary': 643,
#  'knw': 644,
#  'person': 645,
#  'loan': 646,
#  'spree': 647,
#  'stay': 648,
#  'address': 649,
#  'maximize': 650,
#  'until': 651,
#  'sipix': 652,
#  'pc': 653,
#  'kiss': 654,
#  'gay': 655,
#  'costa': 656,
#  'sol': 657,
#  'sk38xh': 658,
#  'ask': 659,
#  'told': 660,
#  '02': 661,
#  'gn': 662,
#  'zed': 663,
#  'went': 664,
#  'pass': 665,
#  '150pm': 666,
#  'horny': 667,
#  '25p': 668,
#  'sp': 669,
#  'starts': 670,
#  'holder': 671,
#  '1327': 672,
#  'croydon': 673,
#  'cr9': 674,
#  '5wb': 675,
#  'cum': 676,
#  'gud': 677,
#  'link': 678,
#  'card': 679,
#  'thing': 680,
#  'logo': 681,
#  'finished': 682,
#  'car': 683,
#  'arcade': 684,
#  'dis': 685,
#  'sky': 686,
#  '11mths': 687,
#  'download': 688,
#  'partner': 689,
#  'watch': 690,
#  'local': 691,
#  '3510i': 692,
#  'quite': 693,
#  'few': 694,
#  'reference': 695,
#  'super': 696,
#  'singles': 697,
#  '62468': 698,
#  'themob': 699,
#  "won't": 700,
#  'maybe': 701,
#  'decimal': 702,
#  'voda': 703,
#  'quoting': 704,
#  'lol': 705,
#  'goto': 706,
#  'comuk': 707,
#  'extra': 708,
#  'change': 709,
#  'though': 710,
#  'dunno': 711,
#  '2optout': 712,
#  'txtauction': 713,
#  'something': 714,
#  'else': 715,
#  'tot': 716,
#  'fine': 717,
#  'unsub': 718,
#  'luck': 719,
#  'sis': 720,
#  '36504': 721,
#  'al': 722,
#  "u've": 723,
#  'invited': 724,
#  'xchat': 725,
#  'following': 726,
#  'review': 727,
#  'urawinner': 728,
#  'surprise': 729,
#  'anyone': 730,
#  'via': 731,
#  'dinner': 732,
#  'smile': 733,
#  'dad': 734,
#  'wake': 735,
#  'years': 736,
#  '10am': 737,
#  'starting': 738,
#  'pound': 739,
#  'questions': 740,
#  'contacted': 741,
#  'entered': 742,
#  'unlimited': 743,
#  'cc': 744,
#  '28': 745,
#  'awesome': 746,
#  'loyalty': 747,
#  'plan': 748,
#  'break': 749,
#  "uk's": 750,
#  '2nite': 751,
#  'missed': 752,
#  'frnds': 753,
#  '09050090044': 754,
#  'toclaim': 755,
#  'pobox334': 756,
#  'stockport': 757,
#  'cost£1': 758,
#  'max10mins': 759,
#  'hair': 760,
#  '1x150p': 761,
#  'neva': 762,
#  'while': 763,
#  'optout': 764,
#  'app': 765,
#  '20': 766,
#  'linerental': 767,
#  '12': 768,
#  'announcement': 769,
#  'two': 770,
#  'watching': 771,
#  'hear': 772,
#  'pix': 773,
#  'grins': 774,
#  'search': 775,
#  'till': 776,
#  'forget': 777,
#  'lei': 778,
#  'correct': 779,
#  'subscription': 780,
#  'revealed': 781,
#  '82277': 782,
#  '80062': 783,
#  'fantasies': 784,
#  '08707509020': 785,
#  'finish': 786,
#  'dun': 787,
#  'tmr': 788,
#  'remember': 789,
#  'replying': 790,
#  'click': 791,
#  'forwarded': 792,
#  'fantasy': 793,
#  'job': 794,
#  'wish': 795,
#  'set': 796,
#  'bus': 797,
#  '2day': 798,
#  'press': 799,
#  'dream': 800,
#  'beautiful': 801,
#  'ring': 802,
#  'asap': 803,
#  '40gb': 804,
#  'entitled': 805,
#  'sir': 806,
#  '83600': 807,
#  'fone': 808,
#  'original': 809,
#  '3gbp': 810,
#  'll': 811,
#  'once': 812,
#  'movies': 813,
#  'action': 814,
#  'thank': 815,
#  '300': 816,
#  'months': 817,
#  '24': 818,
#  'member': 819,
#  'm263uz': 820,
#  'pa': 821,
#  'adult': 822,
#  'inviting': 823,
#  'eerie': 824,
#  'pobox36504w45wq': 825,
#  'selection': 826,
#  'sport': 827,
#  'eat': 828,
#  'sure': 829,
#  '440': 830,
#  'cds': 831,
#  'com1win150ppmx3age16': 832,
#  'kate': 833,
#  "you've": 834,
#  'king': 835,
#  'bad': 836,
#  'login': 837,
#  'gonna': 838,
#  'b4': 839,
#  '£400': 840,
#  'picked': 841,
#  'actually': 842,
#  'mon': 843,
#  'w1': 844,
#  "i'd": 845,
#  'coming': 846,
#  'vip': 847,
#  'jamster': 848,
#  'locations': 849,
#  'ec2a': 850,
#  'havent': 851,
#  'fault': 852,
#  '7pm': 853,
#  'spent': 854,
#  'w45wq': 855,
#  'norm150p': 856,
#  'y': 857,
#  'msgrcvdhg': 858,
#  'cheap': 859,
#  'lot': 860,
#  '8': 861,
#  '85': 862,
#  'tho': 863,
#  'cup': 864,
#  '87239': 865,
#  'joined': 866,
#  'flirt': 867,
#  'recd': 868,
#  'able': 869,
#  'came': 870,
#  'drop': 871,
#  'mine': 872,
#  'smth': 873,
#  'alert': 874,
#  'alright': 875,
#  'wen': 876,
#  'dat': 877,
#  'moral': 878,
#  'o': 879,
#  '87131': 880,
#  'true': 881,
#  'sale': 882,
#  'refused': 883,
#  "'help'": 884,
#  '250': 885,
#  'post': 886,
#  'because': 887,
#  'hmmm': 888,
#  '09061221066': 889,
#  'fromm': 890,
#  'girls': 891,
#  '60p': 892,
#  'ends': 893,
#  'conditions': 894,
#  'jordan': 895,
#  'hold': 896,
#  'goin': 897,
#  'meeting': 898,
#  'heard': 899,
#  'official': 900,
#  'naughty': 901,
#  'santa': 902,
#  'things': 903,
#  'bslvyl': 904,
#  'plz': 905,
#  'team': 906,
#  'usf': 907,
#  'met': 908,
#  'darlin': 909,
#  'wif': 910,
#  '08715705022': 911,
#  'most': 912,
#  'gone': 913,
#  'bahamas': 914,
#  'cust': 915,
#  'nice': 916,
#  'wont': 917,
#  'tariffs': 918,
#  '86021': 919,
#  'porn': 920,
#  "haven't": 921,
#  'nights': 922,
#  'mths': 923,
#  'movie': 924,
#  'using': 925,
#  '0': 926,
#  '08712405020': 927,
#  '£4': 928,
#  'request': 929,
#  'polyphonic': 930,
#  'hl': 931,
#  'weekends': 932,
#  'princess': 933,
#  'close': 934,
#  'immediately': 935,
#  'jus': 936,
#  'bloomberg': 937,
#  'registered': 938,
#  'sending': 939,
#  '3g': 940,
#  'videophones': 941,
#  'videochat': 942,
#  'java': 943,
#  'dload': 944,
#  'noline': 945,
#  'rentl': 946,
#  'netcollex': 947,
#  'hard': 948,
#  'making': 949,
#  'energy': 950,
#  'calls£1': 951,
#  'profit': 952,
#  'st': 953,
#  'always': 954,
#  "'": 955,
#  'never': 956,
#  'ppm': 957,
#  'company': 958,
#  'tel': 959,
#  'spook': 960,
#  'put': 961,
#  'country': 962,
#  'ntwk': 963,
#  '08001950382': 964,
#  'tenerife': 965,
#  '£900': 966,
#  'email': 967,
#  '8552': 968,
#  'callertune': 969,
#  'weight': 970,
#  'thats': 971,
#  'textpod': 972,
#  'happiness': 973,
#  'blue': 974,
#  '1000s': 975,
#  '80082': 976,
#  'lifetime': 977,
#  'greet': 978,
#  'mean': 979,
#  '0808': 980,
#  '145': 981,
#  '4742': 982,
#  '9am': 983,
#  '11pm': 984,
#  'pod': 985,
#  'deliveredtomorrow': 986,
#  '80488': 987,
#  'found': 988,
#  'subs': 989,
#  '05': 990,
#  'project': 991,
#  'exciting': 992,
#  'xy': 993,
#  '84025': 994,
#  '21': 995,
#  'voicemail': 996,
#  '4u': 997,
#  'title': 998,
#  'titles': 999,
#  'babes': 1000,
#  ...}

# %%
# check how many unique tokens are present
tot_words = len(word_index)
print('There are %s unique tokens in training data. ' % tot_words)
# Out:
# There are 4169 unique tokens in training data.

# %%
# Sequencing and padding 
#train
training_sequences = tokenizer.texts_to_sequences(train_msg)
training_padded = pad_sequences (training_sequences, maxlen = max_len, padding = padding_type, truncating = trunc_type )

#test
testing_sequences = tokenizer.texts_to_sequences(test_msg)
testing_padded = pad_sequences(testing_sequences, maxlen = max_len,padding = padding_type, truncating = trunc_type)

# %%
vocab_size = 500 
embeding_dim = 16
drop_value = 0.2 
n_dense = 24

# %%
from keras.layers import Embedding
model = Sequential()
model.add(Embedding(vocab_size, embeding_dim, input_length=max_len))
model.add(GlobalAveragePooling1D())
model.add(Dense(24, activation='relu'))
model.add(Dropout(drop_value))
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 50, 16)            8000
#
#  global_average_pooling1d (G  (None, 16)               0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 24)                408
#
#  dropout (Dropout)           (None, 24)                0
#
#  dense_1 (Dense)             (None, 1)                 25
#
# =================================================================
# Total params: 8,433
# Trainable params: 8,433
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',optimizer='adam' ,metrics=['accuracy'])

# %%
# fit dense seq model
num_epochs = 30
early_stop = EarlyStopping(monitor='val_loss', patience=3)
history = model.fit(training_padded, train_labels, epochs=num_epochs, validation_data=(testing_padded, test_labels),callbacks =[early_stop], verbose=2)
# Out:
# Epoch 1/30
# 38/38 - 1s - loss: 0.6882 - accuracy: 0.6603 - val_loss: 0.6822 - val_accuracy: 0.7926 - 729ms/epoch - 19ms/step
# Epoch 2/30
# 38/38 - 0s - loss: 0.6683 - accuracy: 0.8335 - val_loss: 0.6546 - val_accuracy: 0.8261 - 92ms/epoch - 2ms/step
# Epoch 3/30
# 38/38 - 0s - loss: 0.6220 - accuracy: 0.8762 - val_loss: 0.5931 - val_accuracy: 0.8495 - 96ms/epoch - 3ms/step
# Epoch 4/30
# 38/38 - 0s - loss: 0.5406 - accuracy: 0.8979 - val_loss: 0.5056 - val_accuracy: 0.8562 - 94ms/epoch - 2ms/step
# Epoch 5/30
# 38/38 - 0s - loss: 0.4415 - accuracy: 0.9004 - val_loss: 0.4144 - val_accuracy: 0.8729 - 92ms/epoch - 2ms/step
# Epoch 6/30
# 38/38 - 0s - loss: 0.3532 - accuracy: 0.9071 - val_loss: 0.3434 - val_accuracy: 0.8896 - 98ms/epoch - 3ms/step
# Epoch 7/30
# 38/38 - 0s - loss: 0.2887 - accuracy: 0.9247 - val_loss: 0.2903 - val_accuracy: 0.8930 - 83ms/epoch - 2ms/step
# Epoch 8/30
# 38/38 - 0s - loss: 0.2367 - accuracy: 0.9289 - val_loss: 0.2580 - val_accuracy: 0.9030 - 94ms/epoch - 2ms/step
# Epoch 9/30
# 38/38 - 0s - loss: 0.2062 - accuracy: 0.9356 - val_loss: 0.2200 - val_accuracy: 0.9164 - 96ms/epoch - 3ms/step
# Epoch 10/30
# 38/38 - 0s - loss: 0.1707 - accuracy: 0.9456 - val_loss: 0.1883 - val_accuracy: 0.9130 - 72ms/epoch - 2ms/step
# Epoch 11/30
# 38/38 - 0s - loss: 0.1538 - accuracy: 0.9548 - val_loss: 0.1675 - val_accuracy: 0.9331 - 83ms/epoch - 2ms/step
# Epoch 12/30
# 38/38 - 0s - loss: 0.1415 - accuracy: 0.9548 - val_loss: 0.1600 - val_accuracy: 0.9331 - 114ms/epoch - 3ms/step
# Epoch 13/30
# 38/38 - 0s - loss: 0.1268 - accuracy: 0.9607 - val_loss: 0.1463 - val_accuracy: 0.9398 - 101ms/epoch - 3ms/step
# Epoch 14/30
# 38/38 - 0s - loss: 0.1165 - accuracy: 0.9640 - val_loss: 0.1387 - val_accuracy: 0.9465 - 96ms/epoch - 3ms/step
# Epoch 15/30
# 38/38 - 0s - loss: 0.1061 - accuracy: 0.9665 - val_loss: 0.1406 - val_accuracy: 0.9398 - 98ms/epoch - 3ms/step
# Epoch 16/30
# 38/38 - 0s - loss: 0.0979 - accuracy: 0.9674 - val_loss: 0.1248 - val_accuracy: 0.9498 - 102ms/epoch - 3ms/step
# Epoch 17/30
# 38/38 - 0s - loss: 0.0962 - accuracy: 0.9682 - val_loss: 0.1258 - val_accuracy: 0.9431 - 99ms/epoch - 3ms/step
# Epoch 18/30
# 38/38 - 0s - loss: 0.0890 - accuracy: 0.9699 - val_loss: 0.1246 - val_accuracy: 0.9431 - 100ms/epoch - 3ms/step
# Epoch 19/30
# 38/38 - 0s - loss: 0.0869 - accuracy: 0.9749 - val_loss: 0.1196 - val_accuracy: 0.9431 - 98ms/epoch - 3ms/step
# Epoch 20/30
# 38/38 - 0s - loss: 0.0791 - accuracy: 0.9707 - val_loss: 0.1150 - val_accuracy: 0.9431 - 100ms/epoch - 3ms/step
# Epoch 21/30
# 38/38 - 0s - loss: 0.0745 - accuracy: 0.9732 - val_loss: 0.1149 - val_accuracy: 0.9532 - 100ms/epoch - 3ms/step
# Epoch 22/30
# 38/38 - 0s - loss: 0.0711 - accuracy: 0.9732 - val_loss: 0.1145 - val_accuracy: 0.9565 - 111ms/epoch - 3ms/step
# Epoch 23/30
# 38/38 - 0s - loss: 0.0702 - accuracy: 0.9791 - val_loss: 0.1156 - val_accuracy: 0.9532 - 107ms/epoch - 3ms/step
# Epoch 24/30
# 38/38 - 0s - loss: 0.0660 - accuracy: 0.9791 - val_loss: 0.1130 - val_accuracy: 0.9498 - 107ms/epoch - 3ms/step
# Epoch 25/30
# 38/38 - 0s - loss: 0.0661 - accuracy: 0.9757 - val_loss: 0.1244 - val_accuracy: 0.9365 - 104ms/epoch - 3ms/step
# Epoch 26/30
# 38/38 - 0s - loss: 0.0626 - accuracy: 0.9816 - val_loss: 0.1228 - val_accuracy: 0.9398 - 80ms/epoch - 2ms/step
# Epoch 27/30
# 38/38 - 0s - loss: 0.0588 - accuracy: 0.9816 - val_loss: 0.1180 - val_accuracy: 0.9431 - 132ms/epoch - 3ms/step

# %%
# Model performance on test data 
model.evaluate(testing_padded, test_labels)
# Out:
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1180 - accuracy: 0.9431
# [0.11798647046089172, 0.9431437849998474]

# %%
metrics = pd.DataFrame(history.history)
# Rename column
metrics.rename(columns = {'loss': 'Training_Loss', 'accuracy': 'Training_Accuracy', 'val_loss': 'Validation_Loss', 'val_accuracy': 'Validation_Accuracy'}, inplace = True)
def plot_graphs1(var1, var2, string):
    metrics[[var1, var2]].plot()
    plt.title('Training and Validation ' + string)
    plt.xlabel ('Number of epochs')
    plt.ylabel(string)
    plt.legend([var1, var2])
plot_graphs1('Training_Loss', 'Validation_Loss', 'loss')

# %%
#LSTM hyperparameters
n_lstm = 20
drop_lstm =0.2

# %%
#LSTM Spam detection architecture
model1 = Sequential()
model1.add(Embedding(vocab_size, embeding_dim, input_length=max_len))
model1.add(LSTM(n_lstm, dropout=drop_lstm, return_sequences=True))
model1.add(LSTM(n_lstm, dropout=drop_lstm, return_sequences=True))
model1.add(Dense(1, activation='sigmoid'))

# %%
model1.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics=['accuracy'])

# %%
from keras.layers import Dense, Input
from keras.models import Model

# %%
num_epochs = 30
early_stop = EarlyStopping(monitor='val_loss', patience=3)
history = model.fit(training_padded, train_labels, epochs=num_epochs, validation_data=(testing_padded, test_labels),callbacks =[early_stop], verbose=2)
# Out:
# Epoch 1/30
# 38/38 - 0s - loss: 0.0555 - accuracy: 0.9808 - val_loss: 0.1020 - val_accuracy: 0.9532 - 102ms/epoch - 3ms/step
# Epoch 2/30
# 38/38 - 0s - loss: 0.0531 - accuracy: 0.9824 - val_loss: 0.1152 - val_accuracy: 0.9431 - 102ms/epoch - 3ms/step
# Epoch 3/30
# 38/38 - 0s - loss: 0.0533 - accuracy: 0.9799 - val_loss: 0.1198 - val_accuracy: 0.9431 - 99ms/epoch - 3ms/step
# Epoch 4/30
# 38/38 - 0s - loss: 0.0499 - accuracy: 0.9858 - val_loss: 0.1058 - val_accuracy: 0.9498 - 83ms/epoch - 2ms/step

# %%
metrics = pd.DataFrame(history.history)
# Rename column
metrics.rename(columns = {'loss': 'Training_Loss', 'accuracy': 'Training_Accuracy',
                         'val_loss': 'Validation_Loss', 'val_accuracy': 'Validation_Accuracy'}, inplace = True)
def plot_graphs1(var1, var2, string):
    metrics[[var1, var2]].plot()
    plt.title('LSTM Model: Training and Validation ' + string)
    plt.xlabel ('Number of epochs')
    plt.ylabel(string)
    plt.legend([var1, var2])
plot_graphs1('Training_Loss', 'Validation_Loss', 'loss')

# %%
# Biderectional LSTM Spam detection architecture
model2 = Sequential()
model2.add(Embedding(vocab_size, embeding_dim, input_length=max_len))
model2.add(Bidirectional(LSTM(n_lstm, dropout=drop_lstm, return_sequences=True)))
model2.add(Dense(1, activation='sigmoid'))

# %%
model2.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics=['accuracy'])

# %%
num_epochs = 30
early_stop = EarlyStopping(monitor='val_loss', patience=2)
history = model.fit(training_padded, train_labels, epochs=num_epochs, validation_data=(testing_padded, test_labels),callbacks =[early_stop], verbose=2)
# Out:
# Epoch 1/30
# 38/38 - 0s - loss: 0.0325 - accuracy: 0.9916 - val_loss: 0.1127 - val_accuracy: 0.9532 - 98ms/epoch - 3ms/step
# Epoch 2/30
# 38/38 - 0s - loss: 0.0302 - accuracy: 0.9916 - val_loss: 0.1331 - val_accuracy: 0.9465 - 85ms/epoch - 2ms/step
# Epoch 3/30
# 38/38 - 0s - loss: 0.0328 - accuracy: 0.9925 - val_loss: 0.1221 - val_accuracy: 0.9498 - 84ms/epoch - 2ms/step

# %%
metrics = pd.DataFrame(history.history)
# Rename column
metrics.rename(columns = {'loss': 'Training_Loss', 'accuracy': 'Training_Accuracy',
                         'val_loss': 'Validation_Loss', 'val_accuracy': 'Validation_Accuracy'}, inplace = True)
def plot_graphs1(var1, var2, string):
    metrics[[var1, var2]].plot()
    plt.title('BiLSTM Model: Training and Validation ' + string)
    plt.xlabel ('Number of epochs')
    plt.ylabel(string)
    plt.legend([var1, var2])
# Plot
plot_graphs1('Training_Loss', 'Validation_Loss', 'loss')

# %%
# Comparing three different models
print(f"Dense architecture loss and accuracy: {model.evaluate(testing_padded, test_labels)} " )
print(f"LSTM architecture loss and accuracy: {model.evaluate(testing_padded, test_labels)} " )
print(f"Bi-LSTM architecture loss and accuracy: {model.evaluate(testing_padded, test_labels)} " )
# Out:
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1221 - accuracy: 0.9498
# Dense architecture loss and accuracy: [0.12207774072885513, 0.9498327970504761]
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1221 - accuracy: 0.9498
# LSTM architecture loss and accuracy: [0.12207774072885513, 0.9498327970504761]
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1221 - accuracy: 0.9498
# Bi-LSTM architecture loss and accuracy: [0.12207774072885513, 0.9498327970504761]

# %%
predict_msg = ["Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...",
          "Ok lar... Joking wif u oni...",
          "Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's"]
# Defining prediction function
def predict_spam(predict_msg):
    new_seq = tokenizer.texts_to_sequences(predict_msg)
    padded = pad_sequences(new_seq, maxlen =max_len,
                      padding = padding_type,
                      truncating=trunc_type)
    return (model.predict(padded))
predict_spam(predict_msg)
# Out:
# 1/1 [==============================] - 0s 69ms/step
# array([[0.00194734],
#        [0.00218369],
#        [0.99999875]], dtype=float32)
